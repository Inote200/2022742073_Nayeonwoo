# %% [markdown]
# state란 무엇인가?
#
# 시스템에 대한 미분 방정식을 푸는데 있어서 과정을 나누어서 풀기 위해 등장된 개념
#
# 시스템을ㄹ 수식화할때 state를 정의해서 그것을 중심으로 풀자
#
# state는 인풋 또는 state끼리 영향을 받는 output은 인풋과 state에 의해서 결정됨.
#
# state를 통해서 미분방정식을 행렬방정식으로 풀수있도록 state variable 도입
#
# 요약하자면 state vaiable 모델이라는건 문제를 푸는 과정 자체에 의미부여를 하기 위한 목적과 컴퓨터 연산을 수행하기 위한 목적

# %%
# %cd /content/drive/MyDrive/Code/colab/2022742073_Nayeonwoo
# Out:
# /content/drive/MyDrive/Code/colab/2022742073_Nayeonwoo

# %%
# !git config --global user.email "nayunwoo159@gmail.com"
# !git config --global user.name "Inote200"

# %%
# !git add "05-01 요약.ipynb"

# %%
# !git pull origin main --rebase
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 930 bytes | 23.00 KiB/s, done.
# From https://github.com/Inote200/2022742073_Nayeonwoo
#  * branch            main       -> FETCH_HEAD
#    254329a..0bb040a  main       -> origin/main
# Updating 254329a..0bb040a
# Fast-forward
#  05-01 | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 05-01

# %%
# !git add "05-01.ipynb"
# !git commit -m "Add new Markdown file"
# !git push origin main
# Out:
# fatal: pathspec '05-01.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	"05-01 \341\204\213\341\205\255\341\204\213\341\205\243\341\206\250.ipynb"
#
# nothing added to commit but untracked files present (use "git add" to track)
# ^C
